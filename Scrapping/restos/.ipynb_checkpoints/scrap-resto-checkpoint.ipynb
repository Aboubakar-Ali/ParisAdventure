# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
def scrap():
    # Instancier un navigateur Selenium
    # Ouvrir la page web
    driver = webdriver.Firefox()
    url = "https://www.sortiraparis.com/hotel-restaurant/restaurant"
    driver.get(url)

    # Vous pouvez ensuite utiliser les méthodes de Selenium pour extraire les données de la page
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    
    # Recherchez les éléments avec la classe "grid"
    links = soup.find_all(class_='col-xs-12')
    
    # Créez une liste pour stocker les liens
    liste_liens = []

    # Parcourez tous les éléments "grid" et extrayez les liens
    for element in links:
        link_element = element.find('a')
        if link_element:
            link = link_element.get('href')
            # Vérifiez si l'URL commence par "http://" ou "https://"
            if not link.startswith("http"):
                # Si ce n'est pas le cas, ajoutez "https://www.sortiraparis.com"
                link = "https://www.sortiraparis.com" + link
            liste_liens.append(link)

    # N'oubliez pas de fermer le navigateur à la fin
    driver.quit()
    
    return liste_liens

# %%
a = scrap()
print(a)
# Out:
# ['https://www.sortiraparis.com/en/where-to-eat-in-paris/restaurant', 'https://www.sortiraparis.com/', 'http://www.facebook.com/pages/Sortirapariscom/127350584025797', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/302384-bistrot-podium-le-nouveau-restaurant-festif-glenn-viel-et-les-bistrots-pas-parisiens-se-devoile', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/276897-passionne-le-restaurant-gastronomique-du-paris-9eme', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/276897-passionne-le-restaurant-gastronomique-du-paris-9eme', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/276897-passionne-le-restaurant-gastronomique-du-paris-9eme', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/276897-passionne-le-restaurant-gastronomique-du-paris-9eme', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303707-addomme-la-nouvelle-sensation-napolitaine-du-marais-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303707-addomme-la-nouvelle-sensation-napolitaine-du-marais-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303707-addomme-la-nouvelle-sensation-napolitaine-du-marais-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/281096-sphere-le-beau-restaurant-gastronomique-rue-de-la-boetie-paris-8e', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/281096-sphere-le-beau-restaurant-gastronomique-rue-de-la-boetie-paris-8e', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/281096-sphere-le-beau-restaurant-gastronomique-rue-de-la-boetie-paris-8e', 'https://www.sortiraparis.com/hotel-restaurant/bar-cafes/articles/260278-la-reserve-du-terroir-le-bar-a-vin-aveyronais-a-tester-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/bar-cafes/articles/260278-la-reserve-du-terroir-le-bar-a-vin-aveyronais-a-tester-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/bar-cafes/articles/260278-la-reserve-du-terroir-le-bar-a-vin-aveyronais-a-tester-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/cafe-tea-time/articles/303762-le-nouveau-brunch-a-volonte-de-la-petite-halle-19e-avec-pizzas-cuites-au-four-a-bois', 'https://www.sortiraparis.com/hotel-restaurant/cafe-tea-time/articles/303762-le-nouveau-brunch-a-volonte-de-la-petite-halle-19e-avec-pizzas-cuites-au-four-a-bois', 'https://www.sortiraparis.com/hotel-restaurant/cafe-tea-time/articles/303762-le-nouveau-brunch-a-volonte-de-la-petite-halle-19e-avec-pizzas-cuites-au-four-a-bois', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/261817-oma-le-delicieux-restaurant-franco-coreen-de-la-cheffe-ji-hye-park-dans-l-hotel-chateau-des-fleurs', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/261817-oma-le-delicieux-restaurant-franco-coreen-de-la-cheffe-ji-hye-park-dans-l-hotel-chateau-des-fleurs', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/261817-oma-le-delicieux-restaurant-franco-coreen-de-la-cheffe-ji-hye-park-dans-l-hotel-chateau-des-fleurs', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303635-le-cambodge-l-adresse-copieuse-aux-specialites-cambodgiennes-et-vietnamiennes-a-petit-prix', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303635-le-cambodge-l-adresse-copieuse-aux-specialites-cambodgiennes-et-vietnamiennes-a-petit-prix', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303635-le-cambodge-l-adresse-copieuse-aux-specialites-cambodgiennes-et-vietnamiennes-a-petit-prix', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303673-selva-une-cuisine-sud-americaine-exotique-et-creative-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303673-selva-une-cuisine-sud-americaine-exotique-et-creative-a-paris', 'https://www.sortiraparis.com/hotel-restaurant/restaurant/articles/303673-selva-une-cuisine-sud-americaine- ...

# %%
def Resto(links):
    name_list = []  # Créez une liste pour stocker les titres

    for link in links:
        driver = webdriver.Firefox()
        driver.get(link)

        # Attendez quelques secondes pour que la page se charge complètement (vous pouvez ajuster le temps d'attente au besoin)
        time.sleep(5)

        # Utilisez BeautifulSoup pour analyser la page
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'html.parser')

        # Trouvez le texte de la balise h1 avec la classe "post-name"
        infos = soup.find('div', id='practical-info')

        if h1_element:
            name = infos.get_text()
            name_list.append(name)  # Ajoutez le titre à la liste
        else:
            print("N/A")

        # Fermez le navigateur
        driver.quit()

    return name_list  # Renvoie la liste des titres

# %%
print(Resto(a))
