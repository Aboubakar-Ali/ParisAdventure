# %%
import pandas as pd

# get data from csv file
df = pd.read_csv('activities.csv')
df
# Out:
#                                           Nom                      open  \
# 0                             Arc de Triomphe          De 10:00 à 23:00
# 1                             Musée du Louvre          De 09:00 à 18:00
# 2              Cathédrale Notre-Dame de Paris  Ouverture non disponible
# 3                               Musée d'Orsay          De 09:30 à 21:45
# 4                         Le Marais Paris III  Ouverture non disponible
# 5                   Place des Vosges Paris IV          De 00:00 à 23:59
# 6            Musée des Arts Forains Paris XII  Ouverture non disponible
# 7          Parc des Buttes-Chaumont Paris XIX          De 07:00 à 22:00
# 8                       Musée Rodin Paris VII          De 10:00 à 18:30
# 9                        Jardin du Luxembourg          De 07:30 à 16:30
# 10                         Pont Alexandre-III  Ouverture non disponible
# 11                            Sainte-Chapelle          De 09:00 à 17:00
# ...
