# %%
import pandas as pd

# get data from csv file
df = pd.read_csv('restaurants.csv')
df
# Out:
#                                NOM  \
# 0                          Orgueil
# 1                  The Green Goose
# 2                           Cavale
# 3   Pur' - Jean-François Rouquette
# 4                       Chez Nicos
# ..                             ...
# 62              Il Etait Un Square
# 63              La Maison du Knafé
# 64              Les Freres Bretons
# 65           Grains Nobles et Plus
# 66                           Miura
#
#                                               ADRESSE NOTE  \
# 0                6 rue Popincourt, 75011 Paris France  5,0
# 1              19 rue des Boulets, 75011 Paris France  4,5
# 2      40 Rue des Petites Écuries, 75010 Paris France  5,0
# 3   5 Rue de La Paix Park Hyatt Paris, 75002 Paris...  5,0
# 4               44 rue Mouffetard, 75005 Paris France  4,5
# ..                                                ...  ...
# 62              54, Rue Corvisart, 75013 Paris France  5,0
# ...
